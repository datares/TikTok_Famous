# %%
import pandas as pd
from TikTokApi import TikTokApi
from TikTokApi.browser import set_async

# %%
api = TikTokApi()
set_async()

# %%
ht = api.discoverHashtags()
ht
# Out:
# [{'cardItem': {'id': '154531',
#    'type': 3,
#    'cover': 'https://p16-va-default.akamaized.net/obj/musically-maliva-obj/258bf6e8ab7cb04131571665dc8fd625',
#    'title': '#RoomTour',
#    'subTitle': '1.9B views',
#    'description': "What's your room look like?\n",
#    'link': '/tag/RoomTour',
#    'round': False,
#    'playToken': '',
#    'keyToken': '',
#    'extraInfo': {'views': '1900000000',
#     'challengeId': '154531',
#     'challengeName': 'RoomTour'}},
#   'videoList': []},
#  {'cardItem': {'id': '1660486717014022',
#    'type': 3,
#    'cover': 'https://p16-va-default.akamaized.net/obj/musically-maliva-obj/18d1278600d04ae12709798058bcec8a',
#    'title': '#bakingszn',
#    'subTitle': '468.8M views',
#    'description': "From family recipes to seasonal treats, we want to see what you're baking for the holidays.",
#    'link': '/tag/bakingszn',
#    'round': False,
#    'playToken': '',
#    'keyToken': '',
#    'extraInfo': {'views': '468800000',
# ...

# %%
from TikTokApi import TikTokApi
import random
api = TikTokApi.get_instance()
did = random.randint(1111111,9999999)

tiktoks = api.trending(count=500, custom_did=str(did))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-a72fc4cfbf10> in <module>
#       1 from TikTokApi import TikTokApi
#       2 import random
# ----> 3 api = TikTokApi.get_instance()
#       4 did = random.randint(1111111,9999999)
#       5
#
# AttributeError: type object 'TikTokApi' has no attribute 'get_instance'
